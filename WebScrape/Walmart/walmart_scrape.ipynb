# %%
import os
from bs4 import BeautifulSoup as bs
import urllib
import pandas as pd
import json

# %%
url = urllib.request.urlopen('file:///C:/Users/willt/OneDrive/Desktop/project3/WebScrape/Walmart/walmart_pizza.html')
soup = bs(url)

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en"><head nonce="UFyhSoyp0vNFt_Kz"><link href="//dis.criteo.com" rel="dns-prefetch"/><link href="//ib.adnxs.com" rel="dns-prefetch"/><link href="//secure-assets.rubiconproject.com" rel="dns-prefetch"/><link href="//beam.hlserve.com" rel="dns-prefetch"/><link href="//pubads.g.doubleclick.net" rel="dns-prefetch"/><link href="//omniture-ssl.walmart.com" rel="dns-prefetch"/><link href="//omniture.walmart.com" rel="dns-prefetch"/><link href="//p.typekit.net" rel="dns-prefetch"/><link href="//pagead2.googlesyndication.com" rel="dns-prefetch"/><link href="//partner.googleadservices.com" rel="dns-prefetch"/><link href="//tpc.googlesyndication.com" rel="dns-prefetch"/><link href="//beacon.walmart.com" rel="dns-prefetch"/><link href="//b.wal.co" rel="dns-prefetch"/><link href="//i5.walmartimages.com" rel="dns-prefetch"/><meta content="width=device-width" name="viewport"/><meta charset="utf-8"/><meta content="105223049547814" property="fb:app_id"/><link as="font" crossorigin="anonymous" href="https://i5.walmartimages.com/dfw/63fd9f59-a78c/fcfae9b6-2f69-4f89-beed-f0eeb4237946/v1/BogleWeb_subset-Bold.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="https://i5.walmartimages.com/dfw/63fd9f59-a78c/fcfae9b6-2f69-4f89-beed-f0eeb4237946/v1/BogleWeb_subset-Regular.woff2" rel="preload" type="font/woff2"/><script defer="" nonce="UFyhSoyp0vNFt_Kz" src="https://www.walmart.com/px/PXu6b0qd2S/init.js"></script><script nonce="UFyhSoyp0vNFt_Kz">var _bcq = _bcq || [];_bcq.push(['_setOptions', { start_time: (new Date()).getTime(), bd: 'beacon.walmart.com', bh: 'beacon.lightestwithqm.walmart.com', sv: '1.0.59' }]);</script><script async="" nonce="UFyhSoyp0vNFt_Kz" src="//i5.walmartimages.com/beacon/beacon.js?bd=beacon.walmart.com&amp;bh=beacon.lightestwithqm.walmart.com"></script><link as="image" href="//i5.walmartimages.com/dfw/63fd9f59-b3e1/7a569e53-f29a-4c3d-bfaf-6f7a158bfadd/v1/walmartLogo.svg" rel="preload"/><title>pizza - Walmart.com</title><meta content="pizza - Walmart.com" property="og:title"/><meta content="pizza - Walmart.com" name="description" property="og:description"/><meta content="https://i5.walmartimages.com/asr/820508b1-4b45-4f9b-a9fe-ccf14af47d40.f2b306f1eaccb172c3044a845f869037.jpeg?odnHeight=180&amp;odnWidth=180&amp;odnBg=ffffff" property="og:image"/><meta content="13" name="next-head-count"/><link as="style" href="https://i5.walmartimages.com/dfw/63fd9f59-7f10/f39d4daf-be64-4c7a-b470-b7275856c4da/v2/_next/static/css/a6cad371ba458043f84b.css" nonce="UFyhSoyp0vNFt_Kz" rel="preload"/><link data-n-g="" href="https://i5.walmartimages.com/dfw/63fd9f59-7f10/f39d4daf-be64-4c7a-b470-b7275856c4da/v2/_next/static/css/a6cad371ba458043f84b.css" nonce="UFyhSoyp0vNFt_Kz" rel="stylesheet"/><noscript data-n-css="UFyhSoyp0vNFt_Kz"></noscript><script defer="" nomodule="" nonce="UFyhSoyp0vNFt_Kz" src="https://i5.walmartimages.com/dfw/63fd9f59-7f10/f39d4daf-be64-4c7a-b470-b7275856c4da/v2/_next/static/chunks/polyfills-4a4cd472cd681630e092.js"></script><script defer="" nonce="UFyhSoyp0vNFt_Kz" src="https://i5.walmartimages.com/dfw/63fd9f59-7f10/f39d4daf-be64-4c7a-b470-b7275856c4da/v2/_next/static/chunks/114.8a9393ce6f514d1111d4.js"></script><script defer="" nonce="UFyhSoyp0vNFt_Kz" src="https://i5.walmartimages.com/dfw/63fd9f59-7f10/f39d4daf-be64-4c7a-b470-b7275856c4da/v2/_next/static/chunks/5404.c7311845d9a2d5f4eca4.js"></script><script defer="" nonce="UFyhSoyp0vNFt_Kz" src="https://i5.walmartimages.com/dfw/63fd9f59-7f10/f39d4daf-be64-4c7a-b470-b7275856c4da/v2/_next/static/chunks/345.e836dcb95cf580f4c8b6.js"></script><script defer="" nonce="UFyhSoyp0vNFt_Kz" src="https://i5.walmartimages.com/dfw/63fd9f59-7f10/f39d4daf-be64-4c7a-b470-b7275856c4da/v2/_next/static/chunks/1923.60c59f27ac123974a5a3.js"></script><script defer="" nonce="UFyhSoyp0vNFt_Kz" src="https://i5.walmartimages.com/dfw/63fd9f59-7f10/f39d4daf-be64-4c7a-b470-b7275856c4da/v2/_next/static/chunks/513.e2c279cac08a255e6196.js"></script><script defer ...
#   </script><script nonce="UFyhSoyp0vNFt_Kz">    window.globalWorkerMessages = window.globalWorkerMessages || [];
#   </script><script nonce="UFyhSoyp0vNFt_Kz">    window.globalPluginDefinitions.push('https://www.walmart.com/sw-plugins/eperf-optimized-assets-original-url.8b53f51b.js');
#   </script><script nonce="UFyhSoyp0vNFt_Kz">    window.globalWorkerMessages.push({
#       command: 'SET_PLUGIN_FILTER',
#       data: {
#         name: 'eperf-optimized-assets-original-url',
#         filter: {
#       type: "url-host",
#       value: "i5.walmartimages.com"
#     }      }
#     });
#   </script><script nonce="UFyhSoyp0vNFt_Kz">    window.globalWorkerMessages.push({
#       command: 'SET_PLUGIN_STATE',
#       data:{
#         name:'eperf-optimized-assets-original-url',
#         state:'ENABLED'
#       }
#     });
#   </script><script nonce="UFyhSoyp0vNFt_Kz">window.globalPluginDefinitions = window.globalPluginDefinitions || [];window.globalWorkerMessages = window.globalWorkerMessages || [];window.globalPluginDefinitions.push('https://www.walmart.com/sw-plugins/eperf-optimized-assets-metric.6524ad95.js');window.globalWorkerMessages.push({command: 'SET_PLUGIN_FILTER',data: {name: 'eperf-optimized-assets-metric',filter: {type: "and",value: [{type: "or",value: ["i5.walmartimages.com", "i5.wal.co"].map(function(host) {return { type: "url-host", value: host };})},{ type: "sample", value: 0.01 }]}}});window.globalWorkerMessages.push({command: 'SET_PLUGIN_STATE',data:{name:'eperf-optimized-assets-metric',state:'ENABLED',filter: undefined}});window.globalPluginDefinitions.push('https://www.walmart.com/sw-plugins/eperf-optimization-metrics.a586fd7d.js');window.globalWorkerMessages.push({command: 'SET_PLUGIN_FILTER',data: {name: 'eperf-optimization-metrics',filter: {type: "and",value: [{ type: "url-host", value: "i5.walmartimages.com" },{ type: "sample", value: 0.01 }]}}});window.globalWorkerMessages.push({command: 'SET_PLUGIN_STATE',data:{name:'eperf-optimization-metrics',state:'ENABLED',filter: undefined}});window.globalPluginDefinitions.push('https://www.walmart.com/sw-plugins/ecdn-cdn-perf.6524ad95.js');window.globalWorkerMessages.push({command: 'SET_PLUGIN_FILTER',data: {name: 'ecdn-cdn-perf',filter: {type: "and",value: [{ type: "url-host", value: "i5.walmartimages.com" },{ type: "sample", value: 0.01 }]}}});window.globalWorkerMessages.push({command: 'SET_PLUGIN_STATE',data:{name:'ecdn-cdn-perf',state:'ENABLED',filter: undefined}});window.globalPluginDefinitions.push('https://www.walmart.com/sw-plugins/ecdn-cache-status.fe7aa234.js');window.globalWorkerMessages.push({command: 'SET_PLUGIN_FILTER',data: {name: 'ecdn-cache-status',filter: {type: "and",value: [{ type: "url-host", value: "i5.walmartimages.com" },{ type: "sample", value: 0.01 }]}}});window.globalWorkerMessages.push({command: 'SET_PLUGIN_STATE',data:{name:'ecdn-cache-status',state:'ENABLED',filter: undefined}});window.globalPluginDefinitions.push('https://www.walmart.com/sw-plugins/grocery-pwa.5725d7c8.js');window.globalWorkerMessages.push({command: 'SET_PLUGIN_STATE',data:{name:'grocery-pwa',state:'ENABLED',filter: {type: "url-path",value: new RegExp("^/grocery")}}});</script><script nonce="UFyhSoyp0vNFt_Kz">window.globalPluginDefinitions.push('https://www.walmart.com/sw-plugins/latency-tracker.ff42f3d6.js');window.globalWorkerMessages.push({command: 'SET_PLUGIN_FILTER',data: {name: 'latency-tracker',filter: {type: "and",value: [{ type: "url-host", value: "www.walmart.com" },{type: "or",value: [{type: "and",value: [{ type: "method", value: "GET" },{ type: "sample", value: 0.05 }]},{type: "and",value: [{ type: "method", value: "POST" },{ type: "url-path", value: new RegExp("^/orchestra") }]}]}]}}});window.globalWorkerMessages.push({command: 'SET_PLUGIN_STATE',data:{name:'latency-tracker',state:'ENABLED',filter: undefined}});</script><script nonce="UFyhSoyp0vNFt_Kz">window.globalWorkerMessages = window.globalWorkerMessages || [];var patch = {environment: "prod",publish_sampling_rate: 0.01,navigation_preload: "enabled",status_check_url: "https://t3.wal.co/sw/status",status_check_interval_ms: 300000,min_required_memory_gb: 8};window.SERVICE_WORKER_CONFIGURATION = !!window.SERVICE_WORKER_CONFIGURATION? Object.assign(window.SERVICE_WORKER_CONFIGURATION, patch): patch;window.globalWorkerMessages.push({command: 'SET_GLOBAL_FILTER',data: {filter: {type: "or",value: [{ type: "url-host", value: "i5.walmartimages.com" },{ type: "url-host", value: "i5.wal.co" },{ type: "url-host", value: "www.walmart.com" },{type: "and",value: [{ type: "referrer-path", value: new RegExp("^/grocery") },{ type: "url-path", value: new RegExp("^/grocery") }]}]}}});</script><script async="async" defer="defer" nonce="UFyhSoyp0vNFt_Kz" src="/sw-register.js"></script><script nonce="UFyhSoyp0vNFt_Kz">window._pxAppId = 'P ...

# %%
results = soup.find_all('div', class_='h-100 pb1-xl pr4-xl pv1 ph1')


class items: 
  def __init__(self, brand, price):
    self.brand = brand
    self.price = price

#lists for brands and items
item_list = []
brand = []


for result in results:
    # Error handling
    try:
        # Identify and return title of listing
        price = result.find('div', class_='b black f5 mr1 mr2-xl lh-copy f4-l').text   
        brand = result.find('span', class_='f6 f5-l normal dark-gray mb0 mt1 lh-title').text

        
        if (brand and price):
            new_dict = {
                       'brand': brand,
                       'price': price
                       }
            print('-------------')
            print(brand)
            print(price)
    except AttributeError as e:
        print(e)

  # appending instances to list 
    item_list.append( new_dict)
    brands.append(brand)
# Out:
# -------------
# California Pizza Kitchen BBQ Recipe Chicken Crispy Thin Crust Frozen Pizza 14.7 oz.
# $6.14
# -------------
# Tombstone Pepperoni Frozen Pizza 19.3 oz.
# $3.87
# -------------
# DIGIORNO Pepperoni Frozen Pizza on a Rising Crust 27.5 oz.
# $5.27
# -------------
# Great Value Rising Crust Pizza, Pepperoni, 26.6 oz
# $2.78
# -------------
# Totino's Pepperoni Party Pizza Pack! Frozen Pizza, 4 count
# $5.13
# -------------
# Red Baron Classic Crust Pepperoni Pizza, 20.60 oz
# $3.98
# -------------
# Jack's Original Thin Crust Pepperoni Frozen Pizza 14.392 oz.
# $2.98
# -------------
# DIGIORNO Four Cheese Frozen Pizza on a Rising Crust 28.2 oz.
# $5.27
# -------------
# Great Value Rising Crust Three Meat Pizza, 28.8 oz (Frozen)
# $2.78
# -------------
# Red Baron Pizza, Classic Crust Four Meat, 21.95 oz
# $3.98

# %%
full_pizza = {"brands": brands,
                "metadata": item_list}

print(full_pizza)
# Out:
# {'brands': ['California Pizza Kitchen BBQ Recipe Chicken Crispy Thin Crust Frozen Pizza 14.7 oz.', 'Tombstone Pepperoni Frozen Pizza 19.3 oz.', 'DIGIORNO Pepperoni Frozen Pizza on a Rising Crust 27.5 oz.', 'Great Value Rising Crust Pizza, Pepperoni, 26.6 oz', "Totino's Pepperoni Party Pizza Pack! Frozen Pizza, 4 count", 'Red Baron Classic Crust Pepperoni Pizza, 20.60 oz', "Jack's Original Thin Crust Pepperoni Frozen Pizza 14.392 oz.", 'DIGIORNO Four Cheese Frozen Pizza on a Rising Crust 28.2 oz.', 'Great Value Rising Crust Three Meat Pizza, 28.8 oz (Frozen)', 'Red Baron Pizza, Classic Crust Four Meat, 21.95 oz', 'California Pizza Kitchen BBQ Recipe Chicken Crispy Thin Crust Frozen Pizza 14.7 oz.', 'Tombstone Pepperoni Frozen Pizza 19.3 oz.', 'DIGIORNO Pepperoni Frozen Pizza on a Rising Crust 27.5 oz.', 'Great Value Rising Crust Pizza, Pepperoni, 26.6 oz', "Totino's Pepperoni Party Pizza Pack! Frozen Pizza, 4 count", 'Red Baron Classic Crust Pepperoni Pizza, 20.60 oz', "Jack's Original Thin Crust Pepperoni Frozen Pizza 14.392 oz.", 'DIGIORNO Four Cheese Frozen Pizza on a Rising Crust 28.2 oz.', 'Great Value Rising Crust Three Meat Pizza, 28.8 oz (Frozen)', 'Red Baron Pizza, Classic Crust Four Meat, 21.95 oz'], 'metadata': [{'brand': 'California Pizza Kitchen BBQ Recipe Chicken Crispy Thin Crust Frozen Pizza 14.7 oz.', 'price': '$6.14'}, {'brand': 'Tombstone Pepperoni Frozen Pizza 19.3 oz.', 'price': '$3.87'}, {'brand': 'DIGIORNO Pepperoni Frozen Pizza on a Rising Crust 27.5 oz.', 'price': '$5.27'}, {'brand': 'Great Value Rising Crust Pizza, Pepperoni, 26.6 oz', 'price': '$2.78'}, {'brand': "Totino's Pepperoni Party Pizza Pack! Frozen Pizza, 4 count", 'price': '$5.13'}, {'brand': 'Red Baron Classic Crust Pepperoni Pizza, 20.60 oz', 'price': '$3.98'}, {'brand': "Jack's Original Thin Crust Pepperoni Frozen Pizza 14.392 oz.", 'price': '$2.98'}, {'brand': 'DIGIORNO Four Cheese Frozen Pizza on a Rising Crust 28.2 oz.', 'price': '$5.27'}, {'brand': 'Great Value Rising Crust Three Meat Pizza, 28.8 oz (Frozen)', 'price': '$2.78'}, {'brand': 'Red Baron Pizza, Classic Crust Four Meat, 21.95 oz', 'price': '$3.98'}]}

# %%
with open('pizza_one.json', 'w') as fp:
    json.dump(full_pizza, fp)
