# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.wholefoodsmarket.com/search?text=frozen+pizza'

# %%
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                 new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#                 j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#                 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#                 })(window,document,'script','dataLayer','GTM-MMVR7TC');
#   </script>
#   <script defer="" src="https://cdn.optimizely.com/js/9737255642.js">
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="#004e36" name="theme-color"/>
#   <link as="stylesheet" href="/wfm-web-assets/css/main.css" rel="preload"/>
#   <link href="/wfm-web-assets/css/main.css" rel="stylesheet"/>
#   <link as="stylesheet" href="/wfm-web-assets/css/main-header.css" rel="preload"/>
# ...

# %%
results = soup.find_all('div', class_='w-pie--product-tile__content')

for result in results:
    # Error handling
    try:
        # Identify and return title of listing
        header = result.find('span', class_='w-cms--font-disclaimer').text
        title = result.find('h2', class_='w-cms--font-body__sans-bold').text
        # Identify and return price of listing
        price = result.find('b', class_='regular_price').text
        
        if (header and title and price):
            print('-------------')
            print(header)
            print(title)
            print(price)
    except AttributeError as e:
        print(e)
# Out:
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# ...
