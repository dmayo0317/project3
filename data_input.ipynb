# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.walmart.com/search?q=pizza&affinityOverride=store_led'

# %%
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text, 'html.parser')
print(soup.prettify())
# Out:
# <html lang="en">
#  <head>
#   <title>
#    Robot or human?
#   </title>
#   <meta content="width=device-width" name="viewport"/>
#   <style>
#    #sign-in-widget a,
#     #sign-in-widget a:active,
#     #sign-in-widget a:hover {
#         color: #000
#     }
#
#     #sign-in-widget h1 {
#         font-weight: 500;
#         font-size: 20px;
#         font-size: 1.25rem;
#         letter-spacing: -.6px;
#         margin: 1px auto
#     }
#
#     @media (min-width:30em) {
#         #sign-in-widget h1 {
#             margin-top: 24px;
#             font-size: 24px;
#             font-size: 1.5rem
#         }
#     }
#
#     #sign-in-widget {
#         font-family: BogleWeb, Helvetica Neue, Helvetica, Arial, sans-serif
#     }
#
#     #sign-in-widget * {
#         box-sizing: border-box
#     }
#
#     #sign-in-widget .text-right {
#         text-align: right
#     }
#
#     @font-face {
#         font-family: NewYorkIcons;
#         src: url(6255ed72d86ece856725a2d80878bce6.eot);
# ...

# %%
header = result.find('span', class_=).text

# %%
#create a url list to scrape data from all pages
url_list = []
for i in range(1,6):
  url_list.append('https://www.walmart.com/search?q=pizza' + str(i))
url_list
# Out:
# ['https://www.walmart.com/search?q=pizza1',
#  'https://www.walmart.com/search?q=pizza2',
#  'https://www.walmart.com/search?q=pizza3',
#  'https://www.walmart.com/search?q=pizza4',
#  'https://www.walmart.com/search?q=pizza5']

# %%
#Create empty list to store the data
item_names = []
price_list = []

# %%
product_name = bsobj.findAll('div',{'class':'h-100 pb1-xl pr4-xl pv1 ph1'})
product_name
# Out:
# [<div class="h-100 pb1-xl pr4-xl pv1 ph1" style="content-visibility:auto;contain-intrinsic-size:198px 340px"><div class="sans-serif mid-gray relative flex flex-column w-100" data-item-id="4ZB7XB99X4M0"><a class="absolute w-100 h-100 z-1" href="https://wrd.walmart.com/track?tax=976759_976791_5774679_3790397&amp;pltfm=desktop&amp;pt=search&amp;mloc=sp-search-middle&amp;storeId=3058&amp;adUid=JhwHIKmWDC_B3_SShCJiDEnw6BKiYvuicbrU&amp;bt=1&amp;pgId=pizza&amp;pos=1&amp;spQs=7XMTevjRV_2KlD4-Nfw9n5GWkC7Doy024ewknsBPQcFJ2C9opOfrod625iFVCyynA2QP-T3OLTwow9kbiufOihh2UzpaCQB24JQtzLrY0xw&amp;eventST=click&amp;plmt=sp-search-middle~desktop~&amp;rdf=1&amp;rd=https%3A%2F%2Fwww.walmart.com%2Fip%2FCAULIPOWER-Veggie-Stone-fired-Cauliflower-Crust-Pizza-10-9-oz%2F722464215" link-identifier="722464215"><span class="w_DY">CAULIPOWER Veggie Stone-fired Cauliflower Crust Pizza, 10.9 oz<!-- --> </span></a><div class="" data-testid="list-view"><div class=""><div class="h2 relative mb2"></div><div class="relativ
# ...

# %%
for names,price in zip(product_name):
    item_names.append(w_Bd)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-67fdb6fc6829> in <module>
# ----> 1 for names,price in zip(product_name):
#       2     item_names.append(w_Bd)
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
bsobj.findAll('span',{'class':'price display-inline-block arrange-fit price price-main'})[0].findAll('span',{'class':'visuallyhidden'})[0].text)
# Out:
#   File "<ipython-input-86-f54c06d5af94>", line 1
#     bsobj.findAll('span',{'class':'price display-inline-block arrange-fit price price-main'})[0].findAll('span',{'class':'visuallyhidden'})[0].text)
#                                                                                                                                                    ^
# SyntaxError: invalid syntax

# %%
for url in url_list:
  result = requests.get(url)
  bsobj = soup(result.content,'lxml')
  
  product_name = bsobj.findAll('div',{'class':'search-result-product-title gridview'})
  product_price = bsobj.findAll('span',{'class':'price display-inline-block arrange-fit price price-main'})
  for names,price in zip(product_name,product_rating,product_reviews,product_price):
    item_names.append(names.a.span.text.strip())
    item_ratings.append(rating.text)
    item_reviews.append(reviews.text.replace('ratings',''))
    price_list.append(price.findAll('span',{'class':'visuallyhidden'})[0].text)

# %%
# creating a dataframe 
df = pd.DataFrame({'Product_Name':item_names, 'Price':price_list, 'Rating':item_ratings,'No_Of_Reviews':item_reviews}, columns=['Product_Name', 'Price', 'Rating', 'No_Of_Reviews'])
df.head()
# Out:
# Empty DataFrame
# Columns: [Product_Name, Price, Rating, No_Of_Reviews]
# Index: []
